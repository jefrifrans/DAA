# %% [markdown]
# ## bubleSort
# ![image.png](attachment:5c43eea8-2687-43f7-9d96-40a4442bc3b1.png)

# %%
import random
import time
start_time=time.time()
def bubbleSort(array):
    #untuk setiap elemen i didalam n maka
    for i in range(n):
 
        #
        for j in range(0, n-i-1):
            if array[j] > array[j+1] :
                array[j], array[j+1] = array[j+1], array[j]
                
if __name__ == '__main__':
    n= int(input("masukkan nilai n : "))
    array = random.sample(range(2*n),n)
    print('array sebelum bubleSort')
    print(array)
    
    bubbleSort(array)
    print ("array setelah bubleSort:")
    print (array)
    
    print('--- %s seconds ----' %(time.time()-start_time))
# Out:
# masukkan nilai n :  10
# array sebelum bubleSort
# [12, 11, 6, 16, 14, 18, 10, 9, 2, 13]
# array setelah bubleSort:
# [2, 6, 9, 10, 11, 12, 13, 14, 16, 18]
# --- 2.377926826477051 seconds ----

# %%
#optimaze bubleSort swipe dilakukan jika array[i] > array[j]
import random
import time
start_time = time.time()
def bubbleSort(array):
    for i in range(n):
        swapped = False
        #cek perelement dari 0 sampai ke index n-i-1
        #jika array ke [j] lebih besar dari array[i] maka swapped
        for j in range(0, n-i-1): 
            if array[j] > array[j+1] :
                array[j], array[j+1] = array[j+1], array[j]
                swapped = True
            if swapped == False:
                break
                
if __name__ == '__main__':
    n= int(input("masukkan nilai n : "))
    array = random.sample(range(2*n),n)
    print('array sebelum bubleSort')
    print(array)
    
    bubbleSort(array)
    print ("array setelah bubleSort:")
    print (array)
    
    print('--- %s seconds ---' %(time.time()-start_time))
# Out:
# masukkan nilai n :  10
# array sebelum bubleSort
# [10, 7, 13, 12, 17, 2, 14, 11, 4, 18]
# array setelah bubleSort:
# [7, 10, 12, 13, 2, 14, 11, 4, 17, 18]
# --- 1.4690494537353516 seconds ---
