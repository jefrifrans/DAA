# %%
from bigO import BigO
from bigO import algorithm

lib = BigO()

lib.test(algorithm.bubbleSort, "random")
lib.test_all(algorithm.bubbleSort)
lib.runtime(algorithm.bubbleSort, "random", 5000)
lib.runtime(algorithm.insertSort, "reversed", 32)
lib.compare(algorithm.insertSort, algorithm.bubbleSort, "all", 5000)
# Out:
# Running bubbleSort(random array)...
# Completed bubbleSort(random array): O(n^2)
# Running bubbleSort(tests)
# Best : O(n) Time
# Average : O(n^2) Time
# Worst : O(n^2) Time
# Running bubbleSort(len 5000 random array)
# Took 5.31980s to sort bubbleSort(random)
# Running insertSort(len 32 reversed array)
# Took 0.00026s to sort insertSort(reversed)
# Running insertSort(tests) vs bubbleSort(tests)
# insertSort is 31.1% faster than bubbleSort on 7 of 9 cases
# Time Difference: 0.20885s
# {'insertSort': 0.6724672444444446, 'bubbleSort': 0.8813157296296281}

# %%
n = int(input('masukkan nilai n'))
#lib.test(algorithm.bubbleSort,'random')
#lib.test_all(algorithm.bubbleSort)
lib.runtime(algorithm.bubbleSort,'random', n)
# Out:
# masukkan nilai n 100000
# Running bubbleSort(len 100000 random array)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-15b920033650> in <module>
#       2 #lib.test(algorithm.bubbleSort,'random')
#       3 #lib.test_all(algorithm.bubbleSort)
# ----> 4 lib.runtime(algorithm.bubbleSort,'random', n)
#
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\bigO\BigO.py in runtime(self, function, array, size, epoch, prtResult)
#     567             # args = (nums, 0, len(nums) - 1)
#     568             timeStart = default_timer()
# --> 569             result = function(nums)
#     570             timeEnd = default_timer()
#     571
#
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\bigO\algorithm.py in bubbleSort(array)
#      12         for i in range(n - counter):
#      13             if array[i] > array[i + 1]:
# ...

# %%
n= int(input('masukkan nila n'))
#lib.test(algorithm.insertSort,'random')25
#lib.test_all(algorithm.insertSort)
lib.runtime(algorithm.insertSort,'random', n)
# Out:
# masukkan nila n 9
# Running insertSort(len 9 random array)
# Took 0.00001s to sort insertSort(random)
# (1.2700002116616815e-05, [-9, -7, -6, 2, 3, 4, 5, 7, 8])

# %%
from bigO import BigO
from bigO import algorithm

lib = BigO()

#lib.test(algorithm.bubbleSort, "random")
#lib.test_all(algorithm.bubbleSort)
lib.runtime(algorithm.bubbleSort, "random", 5000)
#lib.runtime(algorithm.insertSort, "reversed", 32)
#lib.compare(algorithm.insertSort, algorithm.bubbleSort, "all", 5000)
# Out:
# Running bubbleSort(len 5000 random array)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-6fcc83481159> in <module>
#       6 #lib.test(algorithm.bubbleSort, "random")
#       7 #lib.test_all(algorithm.bubbleSort)
# ----> 8 lib.runtime(algorithm.bubbleSort, "random", 5000)
#       9 #lib.runtime(algorithm.insertSort, "reversed", 32)
#      10 #lib.compare(algorithm.insertSort, algorithm.bubbleSort, "all", 5000)
#
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\bigO\BigO.py in runtime(self, function, array, size, epoch, prtResult)
#     567             # args = (nums, 0, len(nums) - 1)
#     568             timeStart = default_timer()
# --> 569             result = function(nums)
#     570             timeEnd = default_timer()
#     571
#
# ...

# %%
n = int(input('masukkan nilai n'))
lib.runtime(algorithm.mergeSort,'random', n)
# Out:
# masukkan nilai n 4
# Running mergeSort(len 4 random array)
# Took 0.00002s to sort mergeSort(random)
# (1.630000042496249e-05, [-3, -1, 1, 2])

# %%
n = int(input('masukkan nilai n'))
lib.runtime(algorithm.quickSort,'random', n)
# Out:
# masukkan nilai n 1000000
# Running quickSort(len 1000000 random array)
# Took 9.41304s to sort quickSort(random)
# (9.413036199999624,
#  [-999994,
#   -999994,
#   -999992,
#   -999991,
#   -999987,
#   -999987,
#   -999986,
#   -999983,
#   -999983,
#   -999981,
#   -999977,
#   -999976,
#   -999975,
#   -999970,
#   -999970,
#   -999962,
#   -999958,
#   -999955,
#   -999955,
#   -999952,
#   -999952,
#   -999952,
#   -999948,
#   -999947,
#   -999947,
#   -999946,
#   -999933,
#   -999931,
#   -999931,
#   -999930,
#   -999928,
#   -999928,
#   -999926,
#   -999925,
#   -999918,
#   -999917,
#   -999917,
#   -999910,
#   -999910,
#   -999907,
#   -999906,
#   -999903,
#   -999900,
#   -999900,
#   -999899,
#   -999894,
#   -999889,
#   -999889,
#   -999886,
#   -999885,
#   -999885,
#   -999882,
#   -999882,
#   -999880,
#   -999878,
#   -999878,
#   -999867,
#   -999866,
#   -999865,
#   -999865,
#   -999865,
#   -999863,
#   -999862,
#   -999859,
#   -999858,
#   -999856,
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
n = [5, 25, 50, 100, 1000, 10000,100000, 500000, 1000000]
bubbleSort= [0.00002, 0.00015, 0.00045, 0.00290, 0.21874, 18.91473, 101.35627, 353.92108,987.95463]
insertSort= [0.00001, 0.00014, 0.00030, 0.00193, 0.13577, 15.33181, 96.93746, 345.34726,972.61043]
quickSort = [0.00003, 0.00010, 0.00027, 0.00066, 0.03383, 0.06445, 0.66461, 4.28093, 9.41304]
mergeSort = [0.00002, 0.00008, 0.00029, 0.00041, 0.00939, 0.06339, 0.76860, 5.29762, 11.07355]
plt.plot(n,bubbleSort, label='bubbleSort',color='cyan')
plt.plot(n,insertSort, label='inserSort', color='red')
plt.plot(n,quickSort, label='quickSort', color='yellow')
plt.plot(n,mergeSort, label='mergeSort', color= 'blue')
plt.title('Perbandingan Runtime Algoritma bubbleSort, insertSort, mergeSort dan quickSort')
plt.ylabel('runtime(s)')
plt.xlabel('size(n)')
plt.legend()
plt.show()

# %%
n = [5, 25, 50, 100, 1000, 10000,100000, 500000, 1000000]
bubbleSort= [0.00002, 0.00015, 0.00045, 0.00290, 0.21874, 18.91473, 101.35627, 353.92108,987.95463]
plt.plot(n,bubbleSort, label='bubbleSort',color='cyan')
plt.title('Runtime Algoritma bubbleSort')
plt.ylabel('runtime(s)')
plt.xlabel('size(n)')
plt.legend()
plt.show()

# %%
n = [5, 25, 50, 100, 1000, 10000,100000, 500000, 1000000]
insertSort= [0.00001, 0.00014, 0.00030, 0.00193, 0.13577, 15.33181, 96.93746, 345.34726,972.61043]
plt.plot(n,insertSort, label='inserSort', color='red')
plt.title('Runtime Algoritma insertSort')
plt.ylabel('runtime(s)')
plt.xlabel('size(n)')
plt.legend()
plt.show()

# %%
n = [5, 25, 50, 100, 1000, 10000,100000, 500000, 1000000]
quickSort = [0.00003, 0.00010, 0.00027, 0.00066, 0.03383, 0.06445, 0.66461, 4.28093, 9.41304]
plt.plot(n,quickSort, label='quickSort', color='yellow')
plt.title('Runtime Algoritma quickSort')
plt.ylabel('runtime(s)')
plt.xlabel('size(n)')
plt.legend()
plt.show()

# %%
n = [5, 25, 50, 100, 1000, 10000,100000, 500000, 1000000]
plt.plot(n,mergeSort, label='mergeSort', color= 'blue')
plt.title('Runtime Algoritma mergeSort')
plt.ylabel('runtime(s)')
plt.xlabel('size(n)')
plt.legend()
plt.show()

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np
  
# create data
x = [1,2,3,4,5]
y = [3,3,3,3,3]
  
# plot lines
plt.plot(x, y, label = "line 1", linestyle="-")
plt.plot(y, x, label = "line 2", linestyle="--")
plt.plot(x, np.sin(x), label = "curve 1", linestyle="-.")
plt.plot(x, np.cos(x), label = "curve 2", linestyle=":")
plt.legend()
plt.show()

# %%
# Dynamic Programming Python implementation of Matrix
# Chain Multiplication. See the Cormen book for details
# of the following algorithm
import sys
 
# Matrix Ai has dimension p[i-1] x p[i] for i = 1..n
 
def MatrixChainOrder(p, n):
    # For simplicity of the program,
    # one extra row and one
    # extra column are allocated in m[][]. 
    # 0th row and 0th
    # column of m[][] are not used
    m = [[0 for x in range(n)] for x in range(n)]
 
    # m[i, j] = Minimum number of scalar
    # multiplications needed
    # to compute the matrix A[i]A[i + 1]...A[j] =
    # A[i..j] where
    # dimension of A[i] is p[i-1] x p[i]
 
    # cost is zero when multiplying one matrix.
    for i in range(1, n):
        m[i][i] = 0
 
    # L is chain length.
    for L in range(2, n):
        for i in range(1, n-L + 1):
            j = i + L-1
            m[i][j] = sys.maxsize
            for k in range(i, j):
 
                # q = cost / scalar multiplications
                q = m[i][k] + m[k + 1][j] + p[i-1]*p[k]*p[j]
                if q < m[i][j]:
                    m[i][j] = q
 
    return m[1][n-1]
 
# Driver code
arr = [1, 2, 3, 4]
size = len(arr)
 
print("Minimum number of multiplications is " +
      str(MatrixChainOrder(arr, size)))
# Out:
# Minimum number of multiplications is 18

# %%
import sys
import random
dp = [[-1 for i in range(100)] for j in range(100)]

#fungsi untuk perkalian matriks berantai
def matrixChainMemoised(p, i, j):
    if(i == j):
        return 0
     
    if(dp[i][j] != -1):
        return dp[i][j]
     
    dp[i][j] = sys.maxsize
     
    for k in range(i,j):
        dp[i][j] = min(dp[i][j], matrixChainMemoised(p, i, k) + matrixChainMemoised(p, k + 1, j)+ p[i - 1] * p[k] * p[j])
     
    return dp[i][j]
 
def MatrixChainOrder(p,n):
    i = 1
    j = n - 1   
    return matrixChainMemoised(p, i, j)
 
if __name__ == '__main__':
    n= int(input('Masukkan nilai n'))
    array = random.sample(range(10*n),n)
    print(array)
    print("Minimum banyak operasi perkalian adalah",MatrixChainOrder(array, n))
# Out:
# Masukkan nilai n 11
# [75, 35, 23, 51, 49, 98, 9, 74, 64, 54, 90]
# Minimum banyak operasi perkalian adalah 285354
